# %%
import os
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

res = requests.get(url)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    #print(soup)
    title_tag = soup.find('title')
    title_all_tag = soup.find_all('title')
    location_tag = soup.find('location', attrs={'wl_ver' :3 })
    location_tag2 = soup.select_one("location[wl_ver='3']")
    print(type(location_tag))
    print(type(location_tag2))

    loc_tag_all = soup.findAll('location', attrs={'wl_ver' :3})
    loc_tag_all2 = soup.select("location[wl_ver='3']")
    print(type(loc_tag_all))
    print(type(loc_tag_all2))
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>

# %%
def search_city():
    import requests
    from bs4 import BeautifulSoup
    url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'
    res = requests.get(url)
    if res.ok:
        soup = BeautifulSoup(res.text, "html.parser")
        location_tags = soup.find_all('location', attrs={'wl_ver':3})
        korea_location=[]
        for location_tag in location_tags:
            location_dict = {}
            location_dict['province'] = location_tag.find('province').text
            location_dict['city'] = location_tag.find('city').text
           #print(location_dict)

            data_tags = location_tag.find_all('data')
          #  print(data_tags)
            data_list = []
            for data_tag in data_tags:
                data_dict = {}
                data_dict['mode'] = data_tag.find('mode').text
                data_dict['tmEf'] = data_tag.find('tmef').text
                data_dict['wf'] = data_tag.find('wf').text
                data_dict['tmn'] = data_tag.find('tmn').text
                data_dict['tmx'] = data_tag.find('tmx').text
                data_list.append(data_dict)

            location_dict['datas']=data_list
            korea_location.append(location_dict)
            #print(location_dict)
        #for cur in korea_location:
          #  print(f"{cur['province']} : {cur['city']} : {len(cur['datas'])}")
          #   print(korea_location[0])
        return korea_location

search_city()
# Out:
# [{'province': '서울ㆍ인천ㆍ경기도',
#   'city': '서울',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-2',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-2',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '4'}]},
#  {'province': '서울ㆍ인천ㆍ경기도',
#   'city': '인천',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-1',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-1',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '0'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '0'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '0'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '0'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '0'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '0'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '0'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '3'}]},
#  {'province': '서울ㆍ인천ㆍ경기도',
#   'city': '수원',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-3',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-3',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '5'}]},
#  {'province': '서울ㆍ인천ㆍ경기도',
#   'city': '파주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-11',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-11',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-11',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-11',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '4'}]},
#  {'province': '서울ㆍ인천ㆍ경기도',
#   'city': '이천',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-9',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '5'}]},
#  {'province': '서울ㆍ인천ㆍ경기도',
#   'city': '평택',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-3',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-3',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '0'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '0'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '3'}]},
#  {'province': '강원도영서',
#   'city': '춘천',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-10',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-11',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-11',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '4'}]},
#  {'province': '강원도영서',
#   'city': '원주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많고 눈',
#     'tmn': '-4',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많고 눈',
#     'tmn': '-4',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '4'}]},
#  {'province': '강원도영동',
#   'city': '강릉',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-1',
#     'tmx': '6'}]},
#  {'province': '대전ㆍ세종ㆍ충청남도',
#   'city': '대전',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '6'}]},
#  {'province': '대전ㆍ세종ㆍ충청남도',
#   'city': '세종',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-9',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '6'}]},
#  {'province': '대전ㆍ세종ㆍ충청남도',
#   'city': '홍성',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '6'}]},
#  {'province': '충청북도',
#   'city': '청주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '6'}]},
#  {'province': '충청북도',
#   'city': '충주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-10',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '1'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '5'}]},
#  {'province': '충청북도',
#   'city': '영동',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-10',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-9',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '7'}]},
#  {'province': '광주ㆍ전라남도',
#   'city': '광주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 비/눈',
#     'tmn': '-1',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '8'}]},
#  {'province': '광주ㆍ전라남도',
#   'city': '목포',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 비/눈',
#     'tmn': '1',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'}]},
#  {'province': '광주ㆍ전라남도',
#   'city': '여수',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 비/눈',
#     'tmn': '1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '2',
#     'tmx': '8'}]},
#  {'province': '광주ㆍ전라남도',
#   'city': '순천',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 비/눈',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '0',
#     'tmx': '9'}]},
#  {'province': '광주ㆍ전라남도',
#   'city': '광양',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 비/눈',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '0',
#     'tmx': '9'}]},
#  {'province': '광주ㆍ전라남도',
#   'city': '나주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 비/눈',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '9'}]},
#  {'province': '전라북도',
#   'city': '전주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '7'}]},
#  {'province': '전라북도',
#   'city': '군산',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-1',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '6'}]},
#  {'province': '전라북도',
#   'city': '정읍',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-2',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-2',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'}]},
#  {'province': '전라북도',
#   'city': '남원',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '7'}]},
#  {'province': '전라북도',
#   'city': '고창',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-2',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-2',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'}]},
#  {'province': '전라북도',
#   'city': '무주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-10',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '-10',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '흐리고 눈',
#     'tmn': '-3',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '-9',
#     'tmx': '2'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '6'}]},
#  {'province': '부산ㆍ울산ㆍ경상남도',
#   'city': '부산',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-1',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-1',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '0',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '0',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '8'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '9'}]},
#  {'province': '부산ㆍ울산ㆍ경상남도',
#   'city': '울산',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '9'}]},
#  {'province': '부산ㆍ울산ㆍ경상남도',
#   'city': '창원',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '9'}]},
#  {'province': '부산ㆍ울산ㆍ경상남도',
#   'city': '진주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '9'}]},
#  {'province': '부산ㆍ울산ㆍ경상남도',
#   'city': '거창',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '7'}]},
#  {'province': '부산ㆍ울산ㆍ경상남도',
#   'city': '통영',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '8'}]},
#  {'province': '대구ㆍ경상북도',
#   'city': '대구',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '8'}]},
#  {'province': '대구ㆍ경상북도',
#   'city': '안동',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-9',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-7',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-7',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-8',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-8',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '6'}]},
#  {'province': '대구ㆍ경상북도',
#   'city': '포항',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '8'}]},
#  {'province': '대구ㆍ경상북도',
#   'city': '경주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '9'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-5',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-6',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-6',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-5',
#     'tmx': '8'}]},
#  {'province': '대구ㆍ경상북도',
#   'city': '울진',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-3',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '-4',
#     'tmx': '5'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '-3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '-2',
#     'tmx': '7'}]},
#  {'province': '대구ㆍ경상북도',
#   'city': '울릉도',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '1',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '맑음',
#     'tmn': '1',
#     'tmx': '5'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '맑음',
#     'tmn': '0',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '맑음',
#     'tmn': '0',
#     'tmx': '4'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '2'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '3'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '-1',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '맑음',
#     'tmn': '0',
#     'tmx': '3'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '맑음',
#     'tmn': '0',
#     'tmx': '4'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '구름많음',
#     'tmn': '1',
#     'tmx': '4'}]},
#  {'province': '제주도',
#   'city': '제주',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '2',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐림',
#     'tmn': '5',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '5',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '7'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '6'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '6'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '흐림',
#     'tmn': '3',
#     'tmx': '7'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '흐림',
#     'tmn': '4',
#     'tmx': '9'}]},
#  {'province': '제주도',
#   'city': '서귀포',
#   'datas': [{'mode': 'A02',
#     'tmEf': '2022-01-31 00:00',
#     'wf': '맑음',
#     'tmn': '2',
#     'tmx': '11'},
#    {'mode': 'A02',
#     'tmEf': '2022-01-31 12:00',
#     'wf': '구름많음',
#     'tmn': '2',
#     'tmx': '11'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 00:00',
#     'wf': '흐림',
#     'tmn': '5',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-01 12:00',
#     'wf': '구름많음',
#     'tmn': '5',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-02 12:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '10'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-03 12:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '8'},
#    {'mode': 'A02',
#     'tmEf': '2022-02-04 12:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '8'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-05 00:00',
#     'wf': '구름많음',
#     'tmn': '3',
#     'tmx': '8'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-06 00:00',
#     'wf': '흐림',
#     'tmn': '3',
#     'tmx': '9'},
#    {'mode': 'A01',
#     'tmEf': '2022-02-07 00:00',
#     'wf': '흐림',
#     'tmn': '5',
#     'tmx': '10'}]}]

# %%
import json

with open('data\\weather.json', 'w')as file:
    json.dump(search_city(), file)

with open('data\\weather.json', 'r', encoding='utf-8') as file:
    content = file.read()
    json_content = json.loads(content)

print(json_content)
# Out:
# [{'province': '서울ㆍ인천ㆍ경기도', 'city': '서울', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-6', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-2', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-2', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '4'}]}, {'province': '서울ㆍ인천ㆍ경기도', 'city': '인천', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '3'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-5', 'tmx': '3'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-1', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-1', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '0'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-5', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-4', 'tmx': '3'}]}, {'province': '서울ㆍ인천ㆍ경기도', 'city': '수원', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '5'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-7', 'tmx': '5'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-3', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-3', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-03 12:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-04 00:00', 'wf': '맑음', 'tmn': '-8', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-04 12:00', 'wf': '맑음', 'tmn': '-8', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-05 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '1'}, {'mode': 'A01', 'tmEf': '2022-02-06 00:00', 'wf': '맑음', 'tmn': '-7', 'tmx': '2'}, {'mode': 'A01', 'tmEf': '2022-02-07 00:00', 'wf': '맑음', 'tmn': '-6', 'tmx': '5'}]}, {'province': '서울ㆍ인천ㆍ경기도', 'city': '파주', 'datas': [{'mode': 'A02', 'tmEf': '2022-01-31 00:00', 'wf': '맑음', 'tmn': '-11', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-01-31 12:00', 'wf': '구름많음', 'tmn': '-11', 'tmx': '4'}, {'mode': 'A02', 'tmEf': '2022-02-01 00:00', 'wf': '구름많고 눈', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-01 12:00', 'wf': '구름많고 눈', 'tmn': '-6', 'tmx': '2'}, {'mode': 'A02', 'tmEf': '2022-02-02 00:00', 'wf': '맑음', 'tmn': '-9', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-02 12:00', 'wf': '맑음', 'tmn': '-9', 'tmx': '1'}, {'mode': 'A02', 'tmEf': '2022-02-03 00:00', 'wf': '맑음', 'tmn' ...
